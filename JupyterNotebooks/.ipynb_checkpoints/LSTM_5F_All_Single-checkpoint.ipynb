# %%
import scipy.io as sio
import matplotlib.pyplot as plt
import numpy as np
import scipy.linalg as la
## Construct LSTM using Tensorflow + Keras
# Import Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import SimpleRNN
from tensorflow.keras.layers import Dropout
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from tensorflow.keras import optimizers


######################################################################
######################################################################
######################################################################
## CSP File from: https://github.com/spolsley/common-spatial-patterns

# CSP takes any number of arguments, but each argument must be a collection of trials associated with a task
# That is, for N tasks, N arrays are passed to CSP each with dimensionality (# of trials of task N) x (feature vector)
# Trials may be of any dimension, provided that each trial for each task has the same dimensionality,
# otherwise there can be no spatial filtering since the trials cannot be compared
def CSP(*tasks):
	if len(tasks) < 2:
		print("Must have at least 2 tasks for filtering.")
		return (None,) * len(tasks)
	else:
		filters = ()
		# CSP algorithm
		# For each task x, find the mean variances Rx and not_Rx, which will be used to compute spatial filter SFx
		iterator = range(0,len(tasks))
		for x in iterator:
			# Find Rx
			Rx = covarianceMatrix(tasks[x][0])
			for t in range(1,len(tasks[x])):
				Rx += covarianceMatrix(tasks[x][t])
			Rx = Rx / len(tasks[x])

			# Find not_Rx
			count = 0
			not_Rx = Rx * 0
			for not_x in [element for element in iterator if element != x]:
				for t in range(0,len(tasks[not_x])):
					not_Rx += covarianceMatrix(tasks[not_x][t])
					count += 1
			not_Rx = not_Rx / count

			# Find the spatial filter SFx
			SFx = spatialFilter(Rx,not_Rx)
			filters += (SFx,)

			# Special case: only two tasks, no need to compute any more mean variances
			if len(tasks) == 2:
				filters += (spatialFilter(not_Rx,Rx),)
				break
		return filters

# covarianceMatrix takes a matrix A and returns the covariance matrix, scaled by the variance
def covarianceMatrix(A):
	Ca = np.dot(A,np.transpose(A))/np.trace(np.dot(A,np.transpose(A)))
	return Ca

# spatialFilter returns the spatial filter SFa for mean covariance matrices Ra and Rb
def spatialFilter(Ra,Rb):
	R = Ra + Rb
	E,U = la.eig(R)

	# CSP requires the eigenvalues E and eigenvector U be sorted in descending order
	ord = np.argsort(E)
	ord = ord[::-1] # argsort gives ascending order, flip to get descending
	E = E[ord]
	U = U[:,ord]

	# Find the whitening transformation matrix
	P = np.dot(np.sqrt(la.inv(np.diag(E))),np.transpose(U))

	# The mean covariance matrices may now be transformed
	Sa = np.dot(P,np.dot(Ra,np.transpose(P)))
	Sb = np.dot(P,np.dot(Rb,np.transpose(P)))

	# Find and sort the generalized eigenvalues and eigenvector
	E1,U1 = la.eig(Sa,Sb)
	ord1 = np.argsort(E1)
	ord1 = ord1[::-1]
	E1 = E1[ord1]
	U1 = U1[:,ord1]

	# The projection matrix (the spatial filter) may now be obtained
	SFa = np.dot(np.transpose(U1),P)
	return SFa.astype(np.float32)
######################################################################
def GetMinSteps(indeces, data):
	minVal = 9999;
	for index in indeces:
		length = data[index].shape[1];
		if(length < minVal):
			minVal = length;
	return minVal
######################################################################
def GetData(indeces, dataIn, truncateValue):
	dataOut = []
	truncate = True;
	if truncateValue == 0:
		truncate = False;
	for idx in indeces:
		currentData = dataIn[idx]
		if truncate:
			dataOut.append(currentData[:,0:truncateValue])
		else:
			dataOut.append(currentData)
	return np.asarray(dataOut)
######################################################################
######################################################################
######################################################################


enableDropout = True;
dropoutPercentage = 0.3;


fileNames = ['5F-SubjectB-160309-5St-SGLHand-HFREQ.mat','5F-SubjectB-160311-5St-SGLHand-HFREQ.mat',\
             '5F-SubjectC-160429-5St-SGLHand-HFREQ.mat','5F-SubjectE-160321-5St-SGLHand-HFREQ.mat',\
			 '5F-SubjectF-160210-5St-SGLHand-HFREQ.mat','5F-SubjectG-160413-5St-SGLHand-HFREQ.mat',\
			 '5F-SubjectG-160428-5St-SGLHand-HFREQ.mat','5F-SubjectH-160804-5St-SGLHand-HFREQ.mat',\
			 '5F-SubjectI-160719-5St-SGLHand-HFREQ.mat','5F-SubjectI-160723-5St-SGLHand-HFREQ.mat'];

numDatasets = len(fileNames);

testAccuracyNoCSP = np.zeros((1,numDatasets))
trainAccuracyNoCSP = np.zeros((1,numDatasets))
testAccuracyWithCSP = np.zeros((1,numDatasets))
trainAccuracyWithCSP = np.zeros((1,numDatasets))

for dataset in range(0, numDatasets):

	fileName = fileNames[dataset];

	file = sio.loadmat('/Users/daniel/Documents/matDown/5F_Data/{}'.format(fileName)) #replace with .mat file name
	header=file['__header__']
	version=file['__version__']
	glob=file['__globals__']
	#ans=file['ans']


	#x=file['x']
	o=file['o'][0][0]
	data=o['data']
	data = np.transpose(data)
	data = data[0:21,:];
	print(data)
	nS=o['nS'][0][0]
	#values of structure seem to be 2D numpy arrays, if originally a scalar in Matlab.
	#use [0][0] to get scalar.
	#print("Number of samples: {numSamples}".format(numSamples=nS))
	test=o['id'][0] #id value became a 1D array of size 1 for some reason. use [0] to get value
	#print("Dataset ID: {id}".format(id=test))
	chnames=o['chnames'][:,0] #[:,0] converts from 2D array back to 1D array
	#print("Channel names: {channelNames}".format(channelNames=chnames))
	markers = o['marker']
	## The markers are all still individual arrays of size 1x1, so we convert them to an array with single values
	markersArray = []
	for marker in markers:
		markersArray.append(marker[0])
	markersArray = np.asarray(markersArray)

	#################################
	#################################
	#5F interaction paradigm
	#1-thumb MI, 2-index finger MI, 3-middle finger MI, 4-ring finger MI, 5-pinkie finger MI

	#all paradigms
	#99-initial relaxation period
	#91-inter-session rest break period
	#92-experiment end
	#################################

	## Find the starting indeces where the marker changes
	changeIdxs = np.where(np.transpose(markersArray)[:-1] != np.transpose(markersArray)[1:])[0]
	#print("Number of index changes: {idxChanges}".format(idxChanges=changeIdxs.shape[0]))
	## Split the data so that it has its matching marker
	dataSplit = np.array_split(data, changeIdxs[:-1], axis=1)
	splitCount = 0
	for splitData in dataSplit:
		splitCount += 1
	#print("Number of arrays in data split: {num}".format(num=splitCount))
	## Retrieve the marker values for each of the change indeces (changeIdxs)
	markerTargets = markersArray[changeIdxs];
	#print("Number of marker targets: {numTargets}".format(numTargets=markerTargets.shape[0]))

	## To Apply CSP, we first only get the indeces for MI tasks 1 and 2 (left and right hand, respectively.)
	tIdx = np.where(markerTargets == 1)[0]
	iIdx = np.where(markerTargets == 2)[0]
	mIdx = np.where(markerTargets == 3)[0]
	rIdx = np.where(markerTargets == 4)[0]
	pIdx = np.where(markerTargets == 5)[0]
	#tCount = tIdx.shape
	#print("Thumb Marker Count: {}\tSize of First: ({},{})".format(tCount, dataSplit[tIdx[0]].shape[0],dataSplit[tIdx[0]].shape[1]))
	#print("Thumb Marker Count: {}\tSize of Second: ({},{})".format(tCount, dataSplit[tIdx[1]].shape[0],dataSplit[tIdx[1]].shape[1]))
	#print("Thumb Marker Count: {}\tSize of Third: ({},{})".format(tCount, dataSplit[tIdx[2]].shape[0],dataSplit[tIdx[2]].shape[1]))


	tIdxMin = GetMinSteps(tIdx, dataSplit)
	iIdxMin = GetMinSteps(iIdx, dataSplit)
	mIdxMin = GetMinSteps(mIdx, dataSplit)
	rIdxMin = GetMinSteps(rIdx, dataSplit)
	pIdxMin = GetMinSteps(pIdx, dataSplit)
	minValues = [tIdxMin, iIdxMin, mIdxMin, rIdxMin, pIdxMin]
	#minValues

	#Truncate the data to the min size
	minValue = np.min(minValues)
	#print(minValue)

	tData = GetData(tIdx, dataSplit, minValue)
	iData = GetData(iIdx, dataSplit, minValue)
	mData = GetData(mIdx, dataSplit, minValue)
	rData = GetData(rIdx, dataSplit, minValue)
	pData = GetData(pIdx, dataSplit, minValue)
	#print("Length of tData: {}".format(len(tData)))
	#print("Length of iData: {}".format(len(iData)))
	#print("Length of mData: {}".format(len(mData)))
	#print("Length of rData: {}".format(len(rData)))
	#print("Length of pData: {}".format(len(pData)))

	minLen = np.min([len(tData), len(iData), len(mData), len(rData), len(pData)])

	##Want to make sure they are balanced, so we keep the minLen values
	tData = tData[0:minLen]
	iData = iData[0:minLen]
	mData = mData[0:minLen]
	rData = rData[0:minLen]
	pData = pData[0:minLen]


	# In[68]:


	#Construct the target arrays and merge the data
	tTargets = np.tile(np.array([1,0,0,0,0]),(minLen,1))
	iTargets = np.tile(np.array([0,1,0,0,0]),(minLen,1))
	mTargets = np.tile(np.array([0,0,1,0,0]),(minLen,1))
	rTargets = np.tile(np.array([0,0,0,1,0]),(minLen,1))
	pTargets = np.tile(np.array([0,0,0,0,1]),(minLen,1))

	markerTargets = np.vstack((tTargets, iTargets, mTargets, rTargets, pTargets))
	FingerData = np.vstack((tData, iData, mData, rData, pData))

	#Sanity Check
	#print("FingerData Shape: {arg1}\tmarkerTargets Shape: {arg2}".format(arg1=FingerData.shape, arg2=markerTargets.shape))

	## Shuffle the data
	FingerData, markerTargets = shuffle(FingerData, markerTargets, random_state=0)

	## Split into train and test sets
	FingerDataTrain, FingerDataTest, markerTargetsTrain, markerTargetsTest = train_test_split(FingerData, markerTargets, test_size=0.3, random_state=1)
	markerTargetsTrain.shape

	## Reshape the data for time-series processing
	## Syntax np.reshape((numExamples, numTimeSteps, numInputs/numFeatures))
	FingerDataTrainRe = FingerDataTrain.reshape((FingerDataTrain.shape[0], FingerDataTrain.shape[1], FingerDataTrain.shape[2]))
	FingerDataTestRe = FingerDataTest.reshape((FingerDataTest.shape[0], FingerDataTest.shape[1], FingerDataTest.shape[2]))

	## Construct the model
	LSTM_EEG = Sequential()
	LSTM_EEG.add(LSTM((100),batch_input_shape=(None,FingerDataTrainRe.shape[1], FingerDataTrainRe.shape[2]), return_sequences=True))
	LSTM_EEG.add(LSTM((50), return_sequences=False))
	LSTM_EEG.add(Dense((5),activation='sigmoid'))

	LSTM_EEG.summary()
	sgd = optimizers.SGD(lr=0.05, decay=1e-6, momentum=0.9, nesterov=True)
	LSTM_EEG.compile(loss='binary_crossentropy', optimizer=sgd, metrics=['accuracy'])


	# In[79]:


	history = LSTM_EEG.fit(FingerDataTrain, markerTargetsTrain, epochs=30,verbose=2, batch_size=16)


	# In[80]:


	predictionsTest = LSTM_EEG.predict(FingerDataTest)


	# In[81]:


	predictionsTest[predictionsTest>0.5] = 1


	# In[82]:


	predictionsTest[predictionsTest <= 0.5] = 0


	# In[83]:


	comparisonArrayTest = predictionsTest == markerTargetsTest


	# In[85]:


	correctCountTest = 0
	for boolValues in comparisonArrayTest:
		if(boolValues[0] & boolValues[1]):
			correctCountTest += 1
	falseCountTest = FingerDataTest.shape[0] - correctCountTest

	predictionsTrain = LSTM_EEG.predict(FingerDataTrain)
	predictionsTrain[predictionsTrain>0.5] = 1;
	predictionsTrain[predictionsTrain<=0.5] = 0;
	comparisonArrayTrain = predictionsTrain == markerTargetsTrain;

	correctCountTrain = 0
	for boolValues in comparisonArrayTrain:
		if(boolValues[0] & boolValues[1]):
			correctCountTrain += 1
	falseCountTrain = FingerDataTrain.shape[0] - correctCountTrain


	# In[87]:
	trainAcc_noCSP = (correctCountTrain*100/FingerDataTrain.shape[0]);
	testAcc_noCSP = (correctCountTest*100/FingerDataTest.shape[0]);

	#Save these values into the array
	trainAccuracyNoCSP[0,dataset] = trainAcc_noCSP;
	testAccuracyNoCSP[0, dataset] = testAcc_noCSP;

	print("#################################")
	print("#################################")
	print("Training Performance:\nCorrect MI Prediction: {}\nIncorrect MI Prediction: {}\nPercent Accuracy: {:.3f}%".format(correctCountTrain, falseCountTrain, trainAcc_noCSP))
	print("#################################")
	print("#################################")
	print("Testing Performance:\nCorrect MI Prediction: {}\nIncorrect MI Prediction: {}\nPercent Accuracy: {:.3f}%".format(correctCountTest, falseCountTest, testAcc_noCSP))
	print("#################################")
	print("#################################")


	# In[88]:


	## Applying CSP to 5F data
	filters = CSP(tData, iData, mData, rData, pData)


	# In[90]:


	filtersArray = np.asarray(filters)


	# In[91]:


	filtersArray.shape


	# In[92]:


	tData_CSP = np.matmul(np.transpose(filtersArray[0]), tData)
	iData_CSP = np.matmul(np.transpose(filtersArray[1]), iData)
	mData_CSP = np.matmul(np.transpose(filtersArray[2]), mData)
	rData_CSP = np.matmul(np.transpose(filtersArray[3]), rData)
	pData_CSP = np.matmul(np.transpose(filtersArray[4]), pData)


	# In[93]:


	FingerData_CSP = np.vstack((tData_CSP, iData_CSP, mData_CSP, rData_CSP, pData_CSP))


	# In[94]:


	#Construct the target arrays and merge the data
	tTargets = np.tile(np.array([1,0,0,0,0]),(minLen,1))
	iTargets = np.tile(np.array([0,1,0,0,0]),(minLen,1))
	mTargets = np.tile(np.array([0,0,1,0,0]),(minLen,1))
	rTargets = np.tile(np.array([0,0,0,1,0]),(minLen,1))
	pTargets = np.tile(np.array([0,0,0,0,1]),(minLen,1))

	markerTargets = np.vstack((tTargets, iTargets, mTargets, rTargets, pTargets))


	# In[95]:


	## Shuffle the data
	FingerData_CSP, markerTargets_CSP = shuffle(FingerData_CSP, markerTargets, random_state=0)
	## Split into train and test sets
	FingerDataTrain_CSP, FingerDataTest_CSP, markerTargetsTrain_CSP, markerTargetsTest_CSP = train_test_split(FingerData_CSP, markerTargets_CSP, test_size=0.3, random_state=1)

	##Use the same model to train and test
	history_CSP = LSTM_EEG.fit(FingerDataTrain_CSP, markerTargetsTrain_CSP, epochs=30,verbose=2, batch_size=16)


	# In[96]:


	predictionsTest = LSTM_EEG.predict(FingerDataTest_CSP)


	# In[97]:


	predictionsTest[predictionsTest>0.5] = 1


	# In[98]:


	predictionsTest[predictionsTest <= 0.5] = 0


	# In[99]:


	comparisonArrayTest = predictionsTest == markerTargetsTest


	# In[100]:


	correctCountTest = 0
	for boolValues in comparisonArrayTest:
		if(boolValues[0] & boolValues[1]):
			correctCountTest += 1
	falseCountTest = FingerDataTest_CSP.shape[0] - correctCountTest

	predictionsTrain = LSTM_EEG.predict(FingerDataTrain_CSP)
	predictionsTrain[predictionsTrain>0.5] = 1;
	predictionsTrain[predictionsTrain<=0.5] = 0;
	comparisonArrayTrain = predictionsTrain == markerTargetsTrain;

	correctCountTrain = 0
	for boolValues in comparisonArrayTrain:
		if(boolValues[0] & boolValues[1]):
			correctCountTrain += 1
	falseCountTrain = FingerDataTrain_CSP.shape[0] - correctCountTrain

	#Computing the accuracy
	trainAcc_wCSP = (correctCountTrain*100/FingerDataTrain_CSP.shape[0]);
	testAcc_wCSP = (correctCountTest*100/FingerDataTest_CSP.shape[0]);

	#Save these values into the array
	trainAccuracyWithCSP[0,dataset] = trainAcc_wCSP;
	testAccuracyWithCSP[0, dataset] = testAcc_wCSP;

	print("#################################")
	print("### RESULTS AFTER APPLYING CSP ##")
	print("#################################")
	print("Training Performance:\nCorrect MI Prediction: {}\nIncorrect MI Prediction: {}\nPercent Accuracy: {:.3f}%".format(correctCountTrain, falseCountTrain, trainAcc_wCSP))
	print("#################################")
	print("#################################")
	print("Testing Performance:\nCorrect MI Prediction: {}\nIncorrect MI Prediction: {}\nPercent Accuracy: {:.3f}%".format(correctCountTest, falseCountTest, testAcc_wCSP))
	print("#################################")
	print("#################################")
# Out:
# [[-0.   -0.   -0.   ... -7.2  -5.94 -0.72]
#  [-0.   -0.   -0.   ... -8.96 -7.28 -7.08]
#  [-0.   -0.   -0.   ...  9.    9.18  9.3 ]
#  ...
#  [-0.   -0.   -0.   ... 27.67  8.23  7.75]
#  [-0.   -0.   -0.   ... 25.41 26.82 29.07]
#  [-0.   -0.   -0.   ... 17.53 16.29 22.08]]
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 21, 100)           550400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dense (Dense)                (None, 5)                 255
# =================================================================
# Total params: 580,855
# Trainable params: 580,855
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 38/38 - 1s - loss: 0.5380 - accuracy: 0.2067
# Epoch 2/30
# 38/38 - 1s - loss: 0.4644 - accuracy: 0.4924
# Epoch 3/30
# 38/38 - 1s - loss: 0.4095 - accuracy: 0.6471
# Epoch 4/30
# 38/38 - 1s - loss: 0.3585 - accuracy: 0.6706
# Epoch 5/30
# 38/38 - 1s - loss: 0.3283 - accuracy: 0.6908
# Epoch 6/30
# 38/38 - 1s - loss: 0.2861 - accuracy: 0.7109
# Epoch 7/30
# 38/38 - 1s - loss: 0.2762 - accuracy: 0.7261
# Epoch 8/30
# 38/38 - 1s - loss: 0.2644 - accuracy: 0.7210
# Epoch 9/30
# 38/38 - 1s - loss: 0.2410 - accuracy: 0.7748
# Epoch 10/30
# 38/38 - 1s - loss: 0.2183 - accuracy: 0.7950
# Epoch 11/30
# 38/38 - 1s - loss: 0.2223 - accuracy: 0.7815
# Epoch 12/30
# 38/38 - 1s - loss: 0.1852 - accuracy: 0.8403
# Epoch 13/30
# 38/38 - 1s - loss: 0.1795 - accuracy: 0.8202
# Epoch 14/30
# 38/38 - 1s - loss: 0.2152 - accuracy: 0.7916
# Epoch 15/30
# 38/38 - 1s - loss: 0.1682 - accuracy: 0.8387
# Epoch 16/30
# 38/38 - 2s - loss: 0.2002 - accuracy: 0.8067
# Epoch 17/30
# 38/38 - 1s - loss: 0.1269 - accuracy: 0.9025
# Epoch 18/30
# 38/38 - 1s - loss: 0.0986 - accuracy: 0.9076
# Epoch 19/30
# 38/38 - 1s - loss: 0.1172 - accuracy: 0.9092
# Epoch 20/30
# 38/38 - 1s - loss: 0.1370 - accuracy: 0.8672
# Epoch 21/30
# 38/38 - 1s - loss: 0.1742 - accuracy: 0.8538
# Epoch 22/30
# 38/38 - 1s - loss: 0.1303 - accuracy: 0.8807
# Epoch 23/30
# 38/38 - 1s - loss: 0.1559 - accuracy: 0.8571
# Epoch 24/30
# 38/38 - 1s - loss: 0.1186 - accuracy: 0.9025
# Epoch 25/30
# 38/38 - 1s - loss: 0.0827 - accuracy: 0.9395
# Epoch 26/30
# 38/38 - 1s - loss: 0.1026 - accuracy: 0.9143
# Epoch 27/30
# 38/38 - 1s - loss: 0.0681 - accuracy: 0.9479
# Epoch 28/30
# 38/38 - 1s - loss: 0.0943 - accuracy: 0.9244
# Epoch 29/30
# 38/38 - 1s - loss: 0.1133 - accuracy: 0.9076
# Epoch 30/30
# 38/38 - 1s - loss: 0.0854 - accuracy: 0.9277
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 577
# Incorrect MI Prediction: 18
# Percent Accuracy: 96.975%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 119
# Incorrect MI Prediction: 136
# Percent Accuracy: 46.667%
# #################################
# #################################
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:93: ComplexWarning: Casting complex values to real discards the imaginary part
# Epoch 1/30
# 38/38 - 1s - loss: 0.6181 - accuracy: 0.3076
# Epoch 2/30
# 38/38 - 1s - loss: 0.4482 - accuracy: 0.4353
# Epoch 3/30
# 38/38 - 1s - loss: 0.3999 - accuracy: 0.5361
# Epoch 4/30
# 38/38 - 1s - loss: 0.3655 - accuracy: 0.5798
# Epoch 5/30
# 38/38 - 1s - loss: 0.3401 - accuracy: 0.6252
# Epoch 6/30
# 38/38 - 1s - loss: 0.3138 - accuracy: 0.6723
# Epoch 7/30
# 38/38 - 1s - loss: 0.2716 - accuracy: 0.7412
# Epoch 8/30
# 38/38 - 1s - loss: 0.2359 - accuracy: 0.7714
# Epoch 9/30
# 38/38 - 1s - loss: 0.2201 - accuracy: 0.7966
# Epoch 10/30
# 38/38 - 1s - loss: 0.1861 - accuracy: 0.8588
# Epoch 11/30
# 38/38 - 1s - loss: 0.1709 - accuracy: 0.8538
# Epoch 12/30
# 38/38 - 1s - loss: 0.1726 - accuracy: 0.8521
# Epoch 13/30
# 38/38 - 1s - loss: 0.1504 - accuracy: 0.8807
# Epoch 14/30
# 38/38 - 1s - loss: 0.1307 - accuracy: 0.9042
# Epoch 15/30
# 38/38 - 1s - loss: 0.1183 - accuracy: 0.9042
# Epoch 16/30
# 38/38 - 1s - loss: 0.0999 - accuracy: 0.9261
# Epoch 17/30
# 38/38 - 1s - loss: 0.0839 - accuracy: 0.9429
# Epoch 18/30
# 38/38 - 1s - loss: 0.0697 - accuracy: 0.9597
# Epoch 19/30
# 38/38 - 1s - loss: 0.0801 - accuracy: 0.9395
# Epoch 20/30
# 38/38 - 1s - loss: 0.0545 - accuracy: 0.9731
# Epoch 21/30
# 38/38 - 1s - loss: 0.0414 - accuracy: 0.9832
# Epoch 22/30
# 38/38 - 1s - loss: 0.0321 - accuracy: 0.9866
# Epoch 23/30
# 38/38 - 1s - loss: 0.0328 - accuracy: 0.9849
# Epoch 24/30
# 38/38 - 1s - loss: 0.0349 - accuracy: 0.9798
# Epoch 25/30
# 38/38 - 1s - loss: 0.0294 - accuracy: 0.9866
# Epoch 26/30
# 38/38 - 1s - loss: 0.0236 - accuracy: 0.9933
# Epoch 27/30
# 38/38 - 1s - loss: 0.0322 - accuracy: 0.9832
# Epoch 28/30
# 38/38 - 1s - loss: 0.0246 - accuracy: 0.9866
# Epoch 29/30
# 38/38 - 1s - loss: 0.0180 - accuracy: 0.9950
# Epoch 30/30
# 38/38 - 1s - loss: 0.0157 - accuracy: 0.9966
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 595
# Incorrect MI Prediction: 0
# Percent Accuracy: 100.000%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 223
# Incorrect MI Prediction: 32
# Percent Accuracy: 87.451%
# #################################
# #################################
# [[ -0.    -0.    -0.   ...  42.98 -11.25 -54.89]
#  [ -0.    -0.    -0.   ...  37.77  -3.2  -57.64]
#  [ -0.    -0.    -0.   ...  36.85  -3.78 -50.66]
#  ...
#  [ -0.    -0.    -0.   ...   7.51 -19.17 -41.75]
#  [ -0.    -0.    -0.   ...  23.26  -0.6  -15.94]
#  [ -0.    -0.    -0.   ...  24.24   6.41 -14.74]]
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 21, 100)           550400
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 580,855
# Trainable params: 580,855
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 38/38 - 1s - loss: 0.5433 - accuracy: 0.2562
# Epoch 2/30
# 38/38 - 1s - loss: 0.4521 - accuracy: 0.5339
# Epoch 3/30
# 38/38 - 1s - loss: 0.3974 - accuracy: 0.6198
# Epoch 4/30
# 38/38 - 1s - loss: 0.3380 - accuracy: 0.7058
# Epoch 5/30
# 38/38 - 1s - loss: 0.3122 - accuracy: 0.7256
# Epoch 6/30
# 38/38 - 1s - loss: 0.2959 - accuracy: 0.7190
# Epoch 7/30
# 38/38 - 1s - loss: 0.2541 - accuracy: 0.7421
# Epoch 8/30
# 38/38 - 1s - loss: 0.2283 - accuracy: 0.7868
# Epoch 9/30
# 38/38 - 1s - loss: 0.2044 - accuracy: 0.8066
# Epoch 10/30
# 38/38 - 1s - loss: 0.1812 - accuracy: 0.8281
# Epoch 11/30
# 38/38 - 1s - loss: 0.1983 - accuracy: 0.8033
# Epoch 12/30
# 38/38 - 1s - loss: 0.2004 - accuracy: 0.8066
# Epoch 13/30
# 38/38 - 1s - loss: 0.1918 - accuracy: 0.8264
# Epoch 14/30
# 38/38 - 1s - loss: 0.1569 - accuracy: 0.8678
# Epoch 15/30
# 38/38 - 1s - loss: 0.1443 - accuracy: 0.8694
# Epoch 16/30
# 38/38 - 1s - loss: 0.1069 - accuracy: 0.9140
# Epoch 17/30
# 38/38 - 1s - loss: 0.1150 - accuracy: 0.9025
# Epoch 18/30
# 38/38 - 1s - loss: 0.1309 - accuracy: 0.8826
# Epoch 19/30
# 38/38 - 2s - loss: 0.1506 - accuracy: 0.8496
# Epoch 20/30
# 38/38 - 1s - loss: 0.1186 - accuracy: 0.8926
# Epoch 21/30
# 38/38 - 1s - loss: 0.1114 - accuracy: 0.9107
# Epoch 22/30
# 38/38 - 1s - loss: 0.0939 - accuracy: 0.9223
# Epoch 23/30
# 38/38 - 1s - loss: 0.1202 - accuracy: 0.8942
# Epoch 24/30
# 38/38 - 1s - loss: 0.1078 - accuracy: 0.9124
# Epoch 25/30
# 38/38 - 1s - loss: 0.1236 - accuracy: 0.8876
# Epoch 26/30
# 38/38 - 1s - loss: 0.1089 - accuracy: 0.9140
# Epoch 27/30
# 38/38 - 1s - loss: 0.0665 - accuracy: 0.9388
# Epoch 28/30
# 38/38 - 1s - loss: 0.0531 - accuracy: 0.9587
# Epoch 29/30
# 38/38 - 1s - loss: 0.0789 - accuracy: 0.9355
# Epoch 30/30
# 38/38 - 1s - loss: 0.0782 - accuracy: 0.9488
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 593
# Incorrect MI Prediction: 12
# Percent Accuracy: 98.017%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 146
# Incorrect MI Prediction: 114
# Percent Accuracy: 56.154%
# #################################
# #################################
# Epoch 1/30
# 38/38 - 1s - loss: 0.5916 - accuracy: 0.3521
# Epoch 2/30
# 38/38 - 1s - loss: 0.4330 - accuracy: 0.4645
# Epoch 3/30
# 38/38 - 1s - loss: 0.3749 - accuracy: 0.5587
# Epoch 4/30
# 38/38 - 1s - loss: 0.3315 - accuracy: 0.6612
# Epoch 5/30
# 38/38 - 1s - loss: 0.2878 - accuracy: 0.7025
# Epoch 6/30
# 38/38 - 1s - loss: 0.2686 - accuracy: 0.7256
# Epoch 7/30
# 38/38 - 2s - loss: 0.2388 - accuracy: 0.7702
# Epoch 8/30
# 38/38 - 1s - loss: 0.2118 - accuracy: 0.8017
# Epoch 9/30
# 38/38 - 1s - loss: 0.1815 - accuracy: 0.8364
# Epoch 10/30
# 38/38 - 1s - loss: 0.1575 - accuracy: 0.8711
# Epoch 11/30
# 38/38 - 1s - loss: 0.1434 - accuracy: 0.8826
# Epoch 12/30
# 38/38 - 1s - loss: 0.1373 - accuracy: 0.8826
# Epoch 13/30
# 38/38 - 1s - loss: 0.1321 - accuracy: 0.8810
# Epoch 14/30
# 38/38 - 1s - loss: 0.1218 - accuracy: 0.9091
# Epoch 15/30
# 38/38 - 1s - loss: 0.1046 - accuracy: 0.9174
# Epoch 16/30
# 38/38 - 1s - loss: 0.1130 - accuracy: 0.9074
# Epoch 17/30
# 38/38 - 1s - loss: 0.1083 - accuracy: 0.9025
# Epoch 18/30
# 38/38 - 1s - loss: 0.1182 - accuracy: 0.8959
# Epoch 19/30
# 38/38 - 2s - loss: 0.0968 - accuracy: 0.9256
# Epoch 20/30
# 38/38 - 1s - loss: 0.0874 - accuracy: 0.9438
# Epoch 21/30
# 38/38 - 2s - loss: 0.0814 - accuracy: 0.9355
# Epoch 22/30
# 38/38 - 1s - loss: 0.0835 - accuracy: 0.9421
# Epoch 23/30
# 38/38 - 1s - loss: 0.0921 - accuracy: 0.9339
# Epoch 24/30
# 38/38 - 1s - loss: 0.0658 - accuracy: 0.9488
# Epoch 25/30
# 38/38 - 1s - loss: 0.0602 - accuracy: 0.9636
# Epoch 26/30
# 38/38 - 1s - loss: 0.0629 - accuracy: 0.9570
# Epoch 27/30
# 38/38 - 1s - loss: 0.0556 - accuracy: 0.9636
# Epoch 28/30
# 38/38 - 1s - loss: 0.0393 - accuracy: 0.9785
# Epoch 29/30
# 38/38 - 1s - loss: 0.0417 - accuracy: 0.9818
# Epoch 30/30
# 38/38 - 1s - loss: 0.0362 - accuracy: 0.9769
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 595
# Incorrect MI Prediction: 10
# Percent Accuracy: 98.347%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 212
# Incorrect MI Prediction: 48
# Percent Accuracy: 81.538%
# #################################
# #################################
# [[ -0.    -0.    -0.   ...  -1.82  -5.38 -28.03]
#  [ -0.    -0.    -0.   ...  20.4   24.46  12.16]
#  [ -0.    -0.    -0.   ... -17.29 -19.51 -33.5 ]
#  ...
#  [ -0.    -0.    -0.   ...   6.83   3.27  -2.46]
#  [ -0.    -0.    -0.   ...  13.19  10.13   4.  ]
#  [ -0.    -0.    -0.   ...  17.37  13.88   4.75]]
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_4 (LSTM)                (None, 21, 100)           550400
# _________________________________________________________________
# lstm_5 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dense_2 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 580,855
# Trainable params: 580,855
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 38/38 - 1s - loss: 0.5338 - accuracy: 0.2622
# Epoch 2/30
# 38/38 - 1s - loss: 0.4329 - accuracy: 0.5345
# Epoch 3/30
# 38/38 - 1s - loss: 0.3562 - accuracy: 0.6891
# Epoch 4/30
# 38/38 - 1s - loss: 0.2948 - accuracy: 0.7429
# Epoch 5/30
# 38/38 - 1s - loss: 0.2803 - accuracy: 0.7311
# Epoch 6/30
# 38/38 - 1s - loss: 0.2691 - accuracy: 0.7210
# Epoch 7/30
# 38/38 - 1s - loss: 0.2624 - accuracy: 0.7445
# Epoch 8/30
# 38/38 - 1s - loss: 0.2402 - accuracy: 0.7765
# Epoch 9/30
# 38/38 - 1s - loss: 0.1853 - accuracy: 0.8420
# Epoch 10/30
# 38/38 - 1s - loss: 0.1747 - accuracy: 0.8319
# Epoch 11/30
# 38/38 - 1s - loss: 0.1767 - accuracy: 0.8370
# Epoch 12/30
# 38/38 - 1s - loss: 0.1336 - accuracy: 0.8958
# Epoch 13/30
# 38/38 - 1s - loss: 0.0992 - accuracy: 0.9176
# Epoch 14/30
# 38/38 - 1s - loss: 0.1208 - accuracy: 0.8874
# Epoch 15/30
# 38/38 - 2s - loss: 0.1397 - accuracy: 0.8739
# Epoch 16/30
# 38/38 - 1s - loss: 0.1334 - accuracy: 0.8706
# Epoch 17/30
# 38/38 - 1s - loss: 0.0784 - accuracy: 0.9395
# Epoch 18/30
# 38/38 - 1s - loss: 0.1213 - accuracy: 0.8790
# Epoch 19/30
# 38/38 - 1s - loss: 0.1161 - accuracy: 0.8924
# Epoch 20/30
# 38/38 - 1s - loss: 0.1131 - accuracy: 0.9025
# Epoch 21/30
# 38/38 - 1s - loss: 0.0537 - accuracy: 0.9647
# Epoch 22/30
# 38/38 - 1s - loss: 0.0503 - accuracy: 0.9664
# Epoch 23/30
# 38/38 - 1s - loss: 0.0978 - accuracy: 0.9042
# Epoch 24/30
# 38/38 - 1s - loss: 0.0830 - accuracy: 0.9378
# Epoch 25/30
# 38/38 - 1s - loss: 0.0673 - accuracy: 0.9462
# Epoch 26/30
# 38/38 - 1s - loss: 0.0583 - accuracy: 0.9563
# Epoch 27/30
# 38/38 - 1s - loss: 0.0734 - accuracy: 0.9412
# Epoch 28/30
# 38/38 - 1s - loss: 0.0432 - accuracy: 0.9647
# Epoch 29/30
# 38/38 - 1s - loss: 0.0870 - accuracy: 0.9244
# Epoch 30/30
# 38/38 - 1s - loss: 0.0617 - accuracy: 0.9529
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 581
# Incorrect MI Prediction: 14
# Percent Accuracy: 97.647%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 160
# Incorrect MI Prediction: 95
# Percent Accuracy: 62.745%
# #################################
# #################################
# Epoch 1/30
# 38/38 - 1s - loss: 0.5368 - accuracy: 0.4017
# Epoch 2/30
# 38/38 - 1s - loss: 0.3708 - accuracy: 0.5933
# Epoch 3/30
# 38/38 - 1s - loss: 0.3081 - accuracy: 0.6555
# Epoch 4/30
# 38/38 - 1s - loss: 0.2589 - accuracy: 0.7563
# Epoch 5/30
# 38/38 - 1s - loss: 0.2139 - accuracy: 0.7664
# Epoch 6/30
# 38/38 - 1s - loss: 0.1840 - accuracy: 0.8303
# Epoch 7/30
# 38/38 - 1s - loss: 0.1606 - accuracy: 0.8571
# Epoch 8/30
# 38/38 - 1s - loss: 0.1611 - accuracy: 0.8571
# Epoch 9/30
# 38/38 - 1s - loss: 0.1357 - accuracy: 0.8739
# Epoch 10/30
# 38/38 - 1s - loss: 0.1370 - accuracy: 0.8706
# Epoch 11/30
# 38/38 - 1s - loss: 0.1291 - accuracy: 0.8857
# Epoch 12/30
# 38/38 - 1s - loss: 0.1064 - accuracy: 0.9042
# Epoch 13/30
# 38/38 - 1s - loss: 0.1055 - accuracy: 0.9008
# Epoch 14/30
# 38/38 - 1s - loss: 0.0827 - accuracy: 0.9361
# Epoch 15/30
# 38/38 - 1s - loss: 0.0890 - accuracy: 0.9160
# Epoch 16/30
# 38/38 - 1s - loss: 0.0719 - accuracy: 0.9496
# Epoch 17/30
# 38/38 - 1s - loss: 0.0741 - accuracy: 0.9345
# Epoch 18/30
# 38/38 - 1s - loss: 0.0594 - accuracy: 0.9630
# Epoch 19/30
# 38/38 - 1s - loss: 0.0622 - accuracy: 0.9546
# Epoch 20/30
# 38/38 - 1s - loss: 0.0503 - accuracy: 0.9630
# Epoch 21/30
# 38/38 - 1s - loss: 0.0505 - accuracy: 0.9613
# Epoch 22/30
# 38/38 - 1s - loss: 0.0380 - accuracy: 0.9731
# Epoch 23/30
# 38/38 - 1s - loss: 0.0340 - accuracy: 0.9765
# Epoch 24/30
# 38/38 - 1s - loss: 0.0241 - accuracy: 0.9866
# Epoch 25/30
# 38/38 - 1s - loss: 0.0168 - accuracy: 0.9950
# Epoch 26/30
# 38/38 - 1s - loss: 0.0088 - accuracy: 0.9983
# Epoch 27/30
# 38/38 - 1s - loss: 0.0085 - accuracy: 0.9966
# Epoch 28/30
# 38/38 - 1s - loss: 0.0056 - accuracy: 0.9983
# Epoch 29/30
# 38/38 - 1s - loss: 0.0044 - accuracy: 1.0000
# Epoch 30/30
# 38/38 - 1s - loss: 0.0033 - accuracy: 1.0000
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 595
# Incorrect MI Prediction: 0
# Percent Accuracy: 100.000%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 207
# Incorrect MI Prediction: 48
# Percent Accuracy: 81.176%
# #################################
# #################################
# [[-0.   -0.   -0.   ...  0.96  0.96  0.95]
#  [-0.   -0.   -0.   ...  3.97  3.96  3.95]
#  [-0.   -0.   -0.   ...  1.67  1.66  1.66]
#  ...
#  [-0.   -0.   -0.   ...  1.13  1.12  1.12]
#  [-0.   -0.   -0.   ...  1.05  1.05  1.05]
#  [-0.   -0.   -0.   ... -0.59 -0.58 -0.58]]
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_6 (LSTM)                (None, 21, 100)           550400
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 580,855
# Trainable params: 580,855
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 38/38 - 1s - loss: 0.5511 - accuracy: 0.2099
# Epoch 2/30
# 38/38 - 1s - loss: 0.4593 - accuracy: 0.4909
# Epoch 3/30
# 38/38 - 1s - loss: 0.3972 - accuracy: 0.6678
# Epoch 4/30
# 38/38 - 1s - loss: 0.3440 - accuracy: 0.7157
# Epoch 5/30
# 38/38 - 1s - loss: 0.3433 - accuracy: 0.6545
# Epoch 6/30
# 38/38 - 1s - loss: 0.3235 - accuracy: 0.6595
# Epoch 7/30
# 38/38 - 1s - loss: 0.2809 - accuracy: 0.7041
# Epoch 8/30
# 38/38 - 1s - loss: 0.2468 - accuracy: 0.7537
# Epoch 9/30
# 38/38 - 1s - loss: 0.2425 - accuracy: 0.7653
# Epoch 10/30
# 38/38 - 1s - loss: 0.2374 - accuracy: 0.7669
# Epoch 11/30
# 38/38 - 1s - loss: 0.2015 - accuracy: 0.8033
# Epoch 12/30
# 38/38 - 1s - loss: 0.2101 - accuracy: 0.7901
# Epoch 13/30
# 38/38 - 1s - loss: 0.1708 - accuracy: 0.8463
# Epoch 14/30
# 38/38 - 1s - loss: 0.1886 - accuracy: 0.8215
# Epoch 15/30
# 38/38 - 1s - loss: 0.1729 - accuracy: 0.8446
# Epoch 16/30
# 38/38 - 1s - loss: 0.1576 - accuracy: 0.8463
# Epoch 17/30
# 38/38 - 1s - loss: 0.1353 - accuracy: 0.8810
# Epoch 18/30
# 38/38 - 1s - loss: 0.1468 - accuracy: 0.8727
# Epoch 19/30
# 38/38 - 1s - loss: 0.1410 - accuracy: 0.8694
# Epoch 20/30
# 38/38 - 1s - loss: 0.1172 - accuracy: 0.8926
# Epoch 21/30
# 38/38 - 1s - loss: 0.1182 - accuracy: 0.8893
# Epoch 22/30
# 38/38 - 1s - loss: 0.1079 - accuracy: 0.9025
# Epoch 23/30
# 38/38 - 1s - loss: 0.1100 - accuracy: 0.9140
# Epoch 24/30
# 38/38 - 1s - loss: 0.1135 - accuracy: 0.8975
# Epoch 25/30
# 38/38 - 1s - loss: 0.1108 - accuracy: 0.9025
# Epoch 26/30
# 38/38 - 1s - loss: 0.1180 - accuracy: 0.9008
# Epoch 27/30
# 38/38 - 1s - loss: 0.0992 - accuracy: 0.9174
# Epoch 28/30
# 38/38 - 1s - loss: 0.1046 - accuracy: 0.9025
# Epoch 29/30
# 38/38 - 1s - loss: 0.0926 - accuracy: 0.9273
# Epoch 30/30
# 38/38 - 1s - loss: 0.0822 - accuracy: 0.9339
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 585
# Incorrect MI Prediction: 20
# Percent Accuracy: 96.694%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 120
# Incorrect MI Prediction: 140
# Percent Accuracy: 46.154%
# #################################
# #################################
# Epoch 1/30
# 38/38 - 1s - loss: 0.5501 - accuracy: 0.3653
# Epoch 2/30
# 38/38 - 1s - loss: 0.4370 - accuracy: 0.4298
# Epoch 3/30
# 38/38 - 1s - loss: 0.4145 - accuracy: 0.4793
# Epoch 4/30
# 38/38 - 1s - loss: 0.3981 - accuracy: 0.5107
# Epoch 5/30
# 38/38 - 1s - loss: 0.3725 - accuracy: 0.5521
# Epoch 6/30
# 38/38 - 1s - loss: 0.3674 - accuracy: 0.5570
# Epoch 7/30
# 38/38 - 1s - loss: 0.3552 - accuracy: 0.5570
# Epoch 8/30
# 38/38 - 1s - loss: 0.3475 - accuracy: 0.6066
# Epoch 9/30
# 38/38 - 1s - loss: 0.3351 - accuracy: 0.6149
# Epoch 10/30
# 38/38 - 1s - loss: 0.3173 - accuracy: 0.6628
# Epoch 11/30
# 38/38 - 1s - loss: 0.2905 - accuracy: 0.6893
# Epoch 12/30
# 38/38 - 1s - loss: 0.2791 - accuracy: 0.6942
# Epoch 13/30
# 38/38 - 1s - loss: 0.2782 - accuracy: 0.7041
# Epoch 14/30
# 38/38 - 1s - loss: 0.2835 - accuracy: 0.7008
# Epoch 15/30
# 38/38 - 1s - loss: 0.2686 - accuracy: 0.7405
# Epoch 16/30
# 38/38 - 1s - loss: 0.2614 - accuracy: 0.7289
# Epoch 17/30
# 38/38 - 1s - loss: 0.2577 - accuracy: 0.7322
# Epoch 18/30
# 38/38 - 1s - loss: 0.2491 - accuracy: 0.7719
# Epoch 19/30
# 38/38 - 1s - loss: 0.2215 - accuracy: 0.7868
# Epoch 20/30
# 38/38 - 1s - loss: 0.2155 - accuracy: 0.8000
# Epoch 21/30
# 38/38 - 1s - loss: 0.2028 - accuracy: 0.8116
# Epoch 22/30
# 38/38 - 1s - loss: 0.1959 - accuracy: 0.8000
# Epoch 23/30
# 38/38 - 1s - loss: 0.1825 - accuracy: 0.8347
# Epoch 24/30
# 38/38 - 1s - loss: 0.1824 - accuracy: 0.8529
# Epoch 25/30
# 38/38 - 1s - loss: 0.1511 - accuracy: 0.8744
# Epoch 26/30
# 38/38 - 1s - loss: 0.1520 - accuracy: 0.8645
# Epoch 27/30
# 38/38 - 1s - loss: 0.1511 - accuracy: 0.8711
# Epoch 28/30
# 38/38 - 1s - loss: 0.1400 - accuracy: 0.8777
# Epoch 29/30
# 38/38 - 1s - loss: 0.1476 - accuracy: 0.8760
# Epoch 30/30
# 38/38 - 1s - loss: 0.1141 - accuracy: 0.9223
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 584
# Incorrect MI Prediction: 21
# Percent Accuracy: 96.529%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 176
# Incorrect MI Prediction: 84
# Percent Accuracy: 67.692%
# #################################
# #################################
# [[ -0.    -0.    -0.   ... -18.87 -29.4  -31.25]
#  [ -0.    -0.    -0.   ... -24.44 -27.89 -31.48]
#  [ -0.    -0.    -0.   ...  -1.01 -13.02 -24.21]
#  ...
#  [ -0.    -0.    -0.   ...  -7.63 -13.89 -15.86]
#  [ -0.    -0.    -0.   ...  -1.5   -3.01  -3.21]
#  [ -0.    -0.    -0.   ...   4.82   1.37   3.95]]
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (None, 21, 100)           550400
# _________________________________________________________________
# lstm_9 (LSTM)                (None, 50)                30200
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 580,855
# Trainable params: 580,855
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 38/38 - 1s - loss: 0.5468 - accuracy: 0.1967
# Epoch 2/30
# 38/38 - 1s - loss: 0.4397 - accuracy: 0.6364
# Epoch 3/30
# 38/38 - 1s - loss: 0.3489 - accuracy: 0.7868
# Epoch 4/30
# 38/38 - 1s - loss: 0.2756 - accuracy: 0.8231
# Epoch 5/30
# 38/38 - 1s - loss: 0.2272 - accuracy: 0.8149
# Epoch 6/30
# 38/38 - 1s - loss: 0.2483 - accuracy: 0.7587
# Epoch 7/30
# 38/38 - 1s - loss: 0.1924 - accuracy: 0.8380
# Epoch 8/30
# 38/38 - 1s - loss: 0.1625 - accuracy: 0.8545
# Epoch 9/30
# 38/38 - 1s - loss: 0.1299 - accuracy: 0.8942
# Epoch 10/30
# 38/38 - 1s - loss: 0.1072 - accuracy: 0.9107
# Epoch 11/30
# 38/38 - 1s - loss: 0.0892 - accuracy: 0.9273
# Epoch 12/30
# 38/38 - 1s - loss: 0.1007 - accuracy: 0.9107
# Epoch 13/30
# 38/38 - 1s - loss: 0.0880 - accuracy: 0.9174
# Epoch 14/30
# 38/38 - 1s - loss: 0.0891 - accuracy: 0.9256
# Epoch 15/30
# 38/38 - 1s - loss: 0.0910 - accuracy: 0.9256
# Epoch 16/30
# 38/38 - 1s - loss: 0.0821 - accuracy: 0.9388
# Epoch 17/30
# 38/38 - 1s - loss: 0.0703 - accuracy: 0.9372
# Epoch 18/30
# 38/38 - 1s - loss: 0.0573 - accuracy: 0.9521
# Epoch 19/30
# 38/38 - 1s - loss: 0.0503 - accuracy: 0.9570
# Epoch 20/30
# 38/38 - 1s - loss: 0.0335 - accuracy: 0.9785
# Epoch 21/30
# 38/38 - 1s - loss: 0.0320 - accuracy: 0.9818
# Epoch 22/30
# 38/38 - 1s - loss: 0.0206 - accuracy: 0.9818
# Epoch 23/30
# 38/38 - 1s - loss: 0.0336 - accuracy: 0.9702
# Epoch 24/30
# 38/38 - 1s - loss: 0.0586 - accuracy: 0.9554
# Epoch 25/30
# 38/38 - 1s - loss: 0.0608 - accuracy: 0.9471
# Epoch 26/30
# 38/38 - 1s - loss: 0.0506 - accuracy: 0.9587
# Epoch 27/30
# 38/38 - 1s - loss: 0.0350 - accuracy: 0.9785
# Epoch 28/30
# 38/38 - 1s - loss: 0.0399 - accuracy: 0.9620
# Epoch 29/30
# 38/38 - 1s - loss: 0.0398 - accuracy: 0.9719
# Epoch 30/30
# 38/38 - 1s - loss: 0.0284 - accuracy: 0.9818
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 599
# Incorrect MI Prediction: 6
# Percent Accuracy: 99.008%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 151
# Incorrect MI Prediction: 109
# Percent Accuracy: 58.077%
# #################################
# #################################
# Epoch 1/30
# 38/38 - 1s - loss: 0.5751 - accuracy: 0.3736
# Epoch 2/30
# 38/38 - 1s - loss: 0.4355 - accuracy: 0.4264
# Epoch 3/30
# 38/38 - 1s - loss: 0.3809 - accuracy: 0.5372
# Epoch 4/30
# 38/38 - 1s - loss: 0.3615 - accuracy: 0.5719
# Epoch 5/30
# 38/38 - 1s - loss: 0.3295 - accuracy: 0.6281
# Epoch 6/30
# 38/38 - 1s - loss: 0.3093 - accuracy: 0.6579
# Epoch 7/30
# 38/38 - 1s - loss: 0.2972 - accuracy: 0.6678
# Epoch 8/30
# 38/38 - 1s - loss: 0.2741 - accuracy: 0.7157
# Epoch 9/30
# 38/38 - 1s - loss: 0.2629 - accuracy: 0.7322
# Epoch 10/30
# 38/38 - 1s - loss: 0.2411 - accuracy: 0.7686
# Epoch 11/30
# 38/38 - 1s - loss: 0.2221 - accuracy: 0.7752
# Epoch 12/30
# 38/38 - 1s - loss: 0.2238 - accuracy: 0.7603
# Epoch 13/30
# 38/38 - 1s - loss: 0.2116 - accuracy: 0.7934
# Epoch 14/30
# 38/38 - 1s - loss: 0.2065 - accuracy: 0.7950
# Epoch 15/30
# 38/38 - 1s - loss: 0.1998 - accuracy: 0.8017
# Epoch 16/30
# 38/38 - 1s - loss: 0.1899 - accuracy: 0.8165
# Epoch 17/30
# 38/38 - 1s - loss: 0.1988 - accuracy: 0.8116
# Epoch 18/30
# 38/38 - 1s - loss: 0.1836 - accuracy: 0.8347
# Epoch 19/30
# 38/38 - 1s - loss: 0.1700 - accuracy: 0.8298
# Epoch 20/30
# 38/38 - 1s - loss: 0.1769 - accuracy: 0.8347
# Epoch 21/30
# 38/38 - 1s - loss: 0.1707 - accuracy: 0.8430
# Epoch 22/30
# 38/38 - 1s - loss: 0.1319 - accuracy: 0.8826
# Epoch 23/30
# 38/38 - 1s - loss: 0.1246 - accuracy: 0.8909
# Epoch 24/30
# 38/38 - 1s - loss: 0.1225 - accuracy: 0.8959
# Epoch 25/30
# 38/38 - 1s - loss: 0.0983 - accuracy: 0.9091
# Epoch 26/30
# 38/38 - 2s - loss: 0.1023 - accuracy: 0.9190
# Epoch 27/30
# 38/38 - 1s - loss: 0.0976 - accuracy: 0.9140
# Epoch 28/30
# 38/38 - 1s - loss: 0.0908 - accuracy: 0.9240
# Epoch 29/30
# 38/38 - 1s - loss: 0.1051 - accuracy: 0.9174
# Epoch 30/30
# 38/38 - 1s - loss: 0.1235 - accuracy: 0.9008
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 554
# Incorrect MI Prediction: 51
# Percent Accuracy: 91.570%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 137
# Incorrect MI Prediction: 123
# Percent Accuracy: 52.692%
# #################################
# #################################
# [[-0.0000e+00 -0.0000e+00 -0.0000e+00 ... -3.1145e+02 -3.1839e+02
#   -3.2213e+02]
#  [-0.0000e+00 -0.0000e+00 -0.0000e+00 ... -8.3500e+01 -9.4060e+01
#   -9.7090e+01]
#  [-0.0000e+00 -0.0000e+00 -0.0000e+00 ... -3.1150e+01 -3.1990e+01
#   -3.1480e+01]
#  ...
#  [-0.0000e+00 -0.0000e+00 -0.0000e+00 ... -4.9980e+01 -6.1930e+01
#   -5.7040e+01]
#  [-0.0000e+00 -0.0000e+00 -0.0000e+00 ... -2.0810e+01 -1.8160e+01
#   -1.8720e+01]
#  [-0.0000e+00 -0.0000e+00 -0.0000e+00 ... -1.2180e+01 -3.4500e+00
#   -1.5000e-01]]
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_10 (LSTM)               (None, 21, 100)           550400
# _________________________________________________________________
# lstm_11 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_5 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 580,855
# Trainable params: 580,855
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 37/37 - 1s - loss: 0.5325 - accuracy: 0.2403
# Epoch 2/30
# 37/37 - 1s - loss: 0.4689 - accuracy: 0.4095
# Epoch 3/30
# 37/37 - 1s - loss: 0.4361 - accuracy: 0.5482
# Epoch 4/30
# 37/37 - 1s - loss: 0.4065 - accuracy: 0.5448
# Epoch 5/30
# 37/37 - 1s - loss: 0.3992 - accuracy: 0.5533
# Epoch 6/30
# 37/37 - 1s - loss: 0.3692 - accuracy: 0.5838
# Epoch 7/30
# 37/37 - 1s - loss: 0.3555 - accuracy: 0.5939
# Epoch 8/30
# 37/37 - 1s - loss: 0.3383 - accuracy: 0.6328
# Epoch 9/30
# 37/37 - 1s - loss: 0.3216 - accuracy: 0.6734
# Epoch 10/30
# 37/37 - 1s - loss: 0.3129 - accuracy: 0.6514
# Epoch 11/30
# 37/37 - 1s - loss: 0.3006 - accuracy: 0.6937
# Epoch 12/30
# 37/37 - 1s - loss: 0.2820 - accuracy: 0.6887
# Epoch 13/30
# 37/37 - 1s - loss: 0.2969 - accuracy: 0.6734
# Epoch 14/30
# 37/37 - 1s - loss: 0.2627 - accuracy: 0.7310
# Epoch 15/30
# 37/37 - 1s - loss: 0.2762 - accuracy: 0.7022
# Epoch 16/30
# 37/37 - 1s - loss: 0.2510 - accuracy: 0.7428
# Epoch 17/30
# 37/37 - 1s - loss: 0.2454 - accuracy: 0.7733
# Epoch 18/30
# 37/37 - 1s - loss: 0.2305 - accuracy: 0.7597
# Epoch 19/30
# 37/37 - 1s - loss: 0.2541 - accuracy: 0.7411
# Epoch 20/30
# 37/37 - 1s - loss: 0.2141 - accuracy: 0.7750
# Epoch 21/30
# 37/37 - 1s - loss: 0.2257 - accuracy: 0.7631
# Epoch 22/30
# 37/37 - 1s - loss: 0.2507 - accuracy: 0.7343
# Epoch 23/30
# 37/37 - 1s - loss: 0.2066 - accuracy: 0.7868
# Epoch 24/30
# 37/37 - 1s - loss: 0.1936 - accuracy: 0.8003
# Epoch 25/30
# 37/37 - 1s - loss: 0.1949 - accuracy: 0.8088
# Epoch 26/30
# 37/37 - 1s - loss: 0.1740 - accuracy: 0.8477
# Epoch 27/30
# 37/37 - 1s - loss: 0.1960 - accuracy: 0.8240
# Epoch 28/30
# 37/37 - 1s - loss: 0.1848 - accuracy: 0.8105
# Epoch 29/30
# 37/37 - 1s - loss: 0.1968 - accuracy: 0.8139
# Epoch 30/30
# 37/37 - 1s - loss: 0.1749 - accuracy: 0.8173
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 530
# Incorrect MI Prediction: 61
# Percent Accuracy: 89.679%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 151
# Incorrect MI Prediction: 103
# Percent Accuracy: 59.449%
# #################################
# #################################
# Epoch 1/30
# 37/37 - 1s - loss: 0.5671 - accuracy: 0.3164
# Epoch 2/30
# 37/37 - 1s - loss: 0.4393 - accuracy: 0.4416
# Epoch 3/30
# 37/37 - 1s - loss: 0.3788 - accuracy: 0.5550
# Epoch 4/30
# 37/37 - 1s - loss: 0.3550 - accuracy: 0.6091
# Epoch 5/30
# 37/37 - 1s - loss: 0.3223 - accuracy: 0.6633
# Epoch 6/30
# 37/37 - 1s - loss: 0.2848 - accuracy: 0.7276
# Epoch 7/30
# 37/37 - 1s - loss: 0.2562 - accuracy: 0.7682
# Epoch 8/30
# 37/37 - 1s - loss: 0.2305 - accuracy: 0.8003
# Epoch 9/30
# 37/37 - 1s - loss: 0.2051 - accuracy: 0.8003
# Epoch 10/30
# 37/37 - 1s - loss: 0.1671 - accuracy: 0.8613
# Epoch 11/30
# 37/37 - 1s - loss: 0.1753 - accuracy: 0.8359
# Epoch 12/30
# 37/37 - 1s - loss: 0.1527 - accuracy: 0.8714
# Epoch 13/30
# 37/37 - 1s - loss: 0.1360 - accuracy: 0.8782
# Epoch 14/30
# 37/37 - 1s - loss: 0.1456 - accuracy: 0.8748
# Epoch 15/30
# 37/37 - 1s - loss: 0.1186 - accuracy: 0.8883
# Epoch 16/30
# 37/37 - 1s - loss: 0.1160 - accuracy: 0.9002
# Epoch 17/30
# 37/37 - 1s - loss: 0.1154 - accuracy: 0.9019
# Epoch 18/30
# 37/37 - 1s - loss: 0.1180 - accuracy: 0.8934
# Epoch 19/30
# 37/37 - 1s - loss: 0.0929 - accuracy: 0.9272
# Epoch 20/30
# 37/37 - 1s - loss: 0.0907 - accuracy: 0.9323
# Epoch 21/30
# 37/37 - 1s - loss: 0.0957 - accuracy: 0.9188
# Epoch 22/30
# 37/37 - 1s - loss: 0.0919 - accuracy: 0.9222
# Epoch 23/30
# 37/37 - 1s - loss: 0.0708 - accuracy: 0.9492
# Epoch 24/30
# 37/37 - 1s - loss: 0.0638 - accuracy: 0.9577
# Epoch 25/30
# 37/37 - 1s - loss: 0.0466 - accuracy: 0.9763
# Epoch 26/30
# 37/37 - 1s - loss: 0.0479 - accuracy: 0.9712
# Epoch 27/30
# 37/37 - 1s - loss: 0.0424 - accuracy: 0.9712
# Epoch 28/30
# 37/37 - 1s - loss: 0.0384 - accuracy: 0.9780
# Epoch 29/30
# 37/37 - 1s - loss: 0.0344 - accuracy: 0.9780
# Epoch 30/30
# 37/37 - 1s - loss: 0.0231 - accuracy: 0.9898
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 590
# Incorrect MI Prediction: 1
# Percent Accuracy: 99.831%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 221
# Incorrect MI Prediction: 33
# Percent Accuracy: 87.008%
# #################################
# #################################
# [[-0.   -0.   -0.   ... 74.23 77.16 90.22]
#  [-0.   -0.   -0.   ... 89.72 88.76 99.06]
#  [-0.   -0.   -0.   ... 27.27 30.92 34.78]
#  ...
#  [-0.   -0.   -0.   ... 17.41 17.95 24.76]
#  [-0.   -0.   -0.   ...  5.52  7.57  7.42]
#  [-0.   -0.   -0.   ...  1.83  3.26  1.84]]
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_12 (LSTM)               (None, 21, 100)           550000
# _________________________________________________________________
# lstm_13 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 580,455
# Trainable params: 580,455
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 38/38 - 1s - loss: 0.5391 - accuracy: 0.1785
# Epoch 2/30
# 38/38 - 1s - loss: 0.4822 - accuracy: 0.3504
# Epoch 3/30
# 38/38 - 1s - loss: 0.4577 - accuracy: 0.4645
# Epoch 4/30
# 38/38 - 1s - loss: 0.4259 - accuracy: 0.5455
# Epoch 5/30
# 38/38 - 1s - loss: 0.4127 - accuracy: 0.5190
# Epoch 6/30
# 38/38 - 1s - loss: 0.3956 - accuracy: 0.5471
# Epoch 7/30
# 38/38 - 1s - loss: 0.3802 - accuracy: 0.5587
# Epoch 8/30
# 38/38 - 1s - loss: 0.3611 - accuracy: 0.5967
# Epoch 9/30
# 38/38 - 1s - loss: 0.3655 - accuracy: 0.5868
# Epoch 10/30
# 38/38 - 2s - loss: 0.3511 - accuracy: 0.6116
# Epoch 11/30
# 38/38 - 4s - loss: 0.3403 - accuracy: 0.6000
# Epoch 12/30
# 38/38 - 4s - loss: 0.3186 - accuracy: 0.6479
# Epoch 13/30
# 38/38 - 3s - loss: 0.2992 - accuracy: 0.6694
# Epoch 14/30
# 38/38 - 3s - loss: 0.3000 - accuracy: 0.6579
# Epoch 15/30
# 38/38 - 4s - loss: 0.3124 - accuracy: 0.6479
# Epoch 16/30
# 38/38 - 3s - loss: 0.2873 - accuracy: 0.6826
# Epoch 17/30
# 38/38 - 2s - loss: 0.2480 - accuracy: 0.7537
# Epoch 18/30
# 38/38 - 2s - loss: 0.2411 - accuracy: 0.7455
# Epoch 19/30
# 38/38 - 1s - loss: 0.2343 - accuracy: 0.7719
# Epoch 20/30
# 38/38 - 1s - loss: 0.2589 - accuracy: 0.7157
# Epoch 21/30
# 38/38 - 1s - loss: 0.2309 - accuracy: 0.7570
# Epoch 22/30
# 38/38 - 1s - loss: 0.2477 - accuracy: 0.7339
# Epoch 23/30
# 38/38 - 1s - loss: 0.2130 - accuracy: 0.7785
# Epoch 24/30
# 38/38 - 1s - loss: 0.1986 - accuracy: 0.8033
# Epoch 25/30
# 38/38 - 1s - loss: 0.2385 - accuracy: 0.7537
# Epoch 26/30
# 38/38 - 1s - loss: 0.1952 - accuracy: 0.8050
# Epoch 27/30
# 38/38 - 1s - loss: 0.2050 - accuracy: 0.7901
# Epoch 28/30
# 38/38 - 1s - loss: 0.1896 - accuracy: 0.8132
# Epoch 29/30
# 38/38 - 1s - loss: 0.1982 - accuracy: 0.7868
# Epoch 30/30
# 38/38 - 1s - loss: 0.1650 - accuracy: 0.8579
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 524
# Incorrect MI Prediction: 81
# Percent Accuracy: 86.612%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 155
# Incorrect MI Prediction: 105
# Percent Accuracy: 59.615%
# #################################
# #################################
# Epoch 1/30
# 38/38 - 1s - loss: 0.6117 - accuracy: 0.2612
# Epoch 2/30
# 38/38 - 1s - loss: 0.4490 - accuracy: 0.4397
# Epoch 3/30
# 38/38 - 1s - loss: 0.3986 - accuracy: 0.5471
# Epoch 4/30
# 38/38 - 1s - loss: 0.3556 - accuracy: 0.6314
# Epoch 5/30
# 38/38 - 1s - loss: 0.2957 - accuracy: 0.7488
# Epoch 6/30
# 38/38 - 1s - loss: 0.2467 - accuracy: 0.7950
# Epoch 7/30
# 38/38 - 1s - loss: 0.2176 - accuracy: 0.8380
# Epoch 8/30
# 38/38 - 1s - loss: 0.1919 - accuracy: 0.8413
# Epoch 9/30
# 38/38 - 1s - loss: 0.1736 - accuracy: 0.8612
# Epoch 10/30
# 38/38 - 1s - loss: 0.1510 - accuracy: 0.8645
# Epoch 11/30
# 38/38 - 1s - loss: 0.1322 - accuracy: 0.8893
# Epoch 12/30
# 38/38 - 1s - loss: 0.1114 - accuracy: 0.9190
# Epoch 13/30
# 38/38 - 1s - loss: 0.1009 - accuracy: 0.9207
# Epoch 14/30
# 38/38 - 1s - loss: 0.0989 - accuracy: 0.9256
# Epoch 15/30
# 38/38 - 1s - loss: 0.0742 - accuracy: 0.9455
# Epoch 16/30
# 38/38 - 1s - loss: 0.0751 - accuracy: 0.9372
# Epoch 17/30
# 38/38 - 1s - loss: 0.0691 - accuracy: 0.9504
# Epoch 18/30
# 38/38 - 1s - loss: 0.0649 - accuracy: 0.9438
# Epoch 19/30
# 38/38 - 1s - loss: 0.0512 - accuracy: 0.9653
# Epoch 20/30
# 38/38 - 1s - loss: 0.0533 - accuracy: 0.9653
# Epoch 21/30
# 38/38 - 1s - loss: 0.0473 - accuracy: 0.9802
# Epoch 22/30
# 38/38 - 1s - loss: 0.0443 - accuracy: 0.9752
# Epoch 23/30
# 38/38 - 1s - loss: 0.0427 - accuracy: 0.9785
# Epoch 24/30
# 38/38 - 1s - loss: 0.0357 - accuracy: 0.9785
# Epoch 25/30
# 38/38 - 1s - loss: 0.0298 - accuracy: 0.9884
# Epoch 26/30
# 38/38 - 1s - loss: 0.0229 - accuracy: 0.9917
# Epoch 27/30
# 38/38 - 1s - loss: 0.0173 - accuracy: 0.9950
# Epoch 28/30
# 38/38 - 1s - loss: 0.0220 - accuracy: 0.9901
# Epoch 29/30
# 38/38 - 1s - loss: 0.0128 - accuracy: 1.0000
# Epoch 30/30
# 38/38 - 1s - loss: 0.0123 - accuracy: 0.9950
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 605
# Incorrect MI Prediction: 0
# Percent Accuracy: 100.000%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 230
# Incorrect MI Prediction: 30
# Percent Accuracy: 88.462%
# #################################
# #################################
# [[ -0.    -0.    -0.   ... 245.35 245.03 239.63]
#  [ -0.    -0.    -0.   ... 352.64 346.92 335.49]
#  [ -0.    -0.    -0.   ...  67.36  68.84  66.67]
#  ...
#  [ -0.    -0.    -0.   ...  69.53  70.07  62.1 ]
#  [ -0.    -0.    -0.   ...  27.02  26.12  20.99]
#  [ -0.    -0.    -0.   ... -41.26 -44.16 -52.29]]
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_14 (LSTM)               (None, 21, 100)           550800
# _________________________________________________________________
# lstm_15 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_7 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 581,255
# Trainable params: 581,255
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 37/37 - 1s - loss: 0.5412 - accuracy: 0.2021
# Epoch 2/30
# 37/37 - 1s - loss: 0.4828 - accuracy: 0.3647
# Epoch 3/30
# 37/37 - 1s - loss: 0.4645 - accuracy: 0.4281
# Epoch 4/30
# 37/37 - 1s - loss: 0.4483 - accuracy: 0.4846
# Epoch 5/30
# 37/37 - 1s - loss: 0.4252 - accuracy: 0.5377
# Epoch 6/30
# 37/37 - 1s - loss: 0.4247 - accuracy: 0.5068
# Epoch 7/30
# 37/37 - 1s - loss: 0.4162 - accuracy: 0.4880
# Epoch 8/30
# 37/37 - 1s - loss: 0.4166 - accuracy: 0.4777
# Epoch 9/30
# 37/37 - 1s - loss: 0.3852 - accuracy: 0.5445
# Epoch 10/30
# 37/37 - 1s - loss: 0.3670 - accuracy: 0.5788
# Epoch 11/30
# 37/37 - 1s - loss: 0.3702 - accuracy: 0.5753
# Epoch 12/30
# 37/37 - 1s - loss: 0.3688 - accuracy: 0.5788
# Epoch 13/30
# 37/37 - 1s - loss: 0.3437 - accuracy: 0.6233
# Epoch 14/30
# 37/37 - 1s - loss: 0.3525 - accuracy: 0.6062
# Epoch 15/30
# 37/37 - 1s - loss: 0.3286 - accuracy: 0.6455
# Epoch 16/30
# 37/37 - 1s - loss: 0.3317 - accuracy: 0.6199
# Epoch 17/30
# 37/37 - 1s - loss: 0.3410 - accuracy: 0.6130
# Epoch 18/30
# 37/37 - 1s - loss: 0.3319 - accuracy: 0.6387
# Epoch 19/30
# 37/37 - 1s - loss: 0.3099 - accuracy: 0.6644
# Epoch 20/30
# 37/37 - 1s - loss: 0.3073 - accuracy: 0.6541
# Epoch 21/30
# 37/37 - 1s - loss: 0.3104 - accuracy: 0.6610
# Epoch 22/30
# 37/37 - 1s - loss: 0.2986 - accuracy: 0.6849
# Epoch 23/30
# 37/37 - 1s - loss: 0.2710 - accuracy: 0.7192
# Epoch 24/30
# 37/37 - 1s - loss: 0.2899 - accuracy: 0.6969
# Epoch 25/30
# 37/37 - 1s - loss: 0.2991 - accuracy: 0.6729
# Epoch 26/30
# 37/37 - 1s - loss: 0.2764 - accuracy: 0.7038
# Epoch 27/30
# 37/37 - 1s - loss: 0.2613 - accuracy: 0.7380
# Epoch 28/30
# 37/37 - 1s - loss: 0.2499 - accuracy: 0.7534
# Epoch 29/30
# 37/37 - 1s - loss: 0.2383 - accuracy: 0.7620
# Epoch 30/30
# 37/37 - 1s - loss: 0.2327 - accuracy: 0.7551
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 513
# Incorrect MI Prediction: 71
# Percent Accuracy: 87.842%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 124
# Incorrect MI Prediction: 127
# Percent Accuracy: 49.402%
# #################################
# #################################
# Epoch 1/30
# 37/37 - 1s - loss: 0.5616 - accuracy: 0.2346
# Epoch 2/30
# 37/37 - 1s - loss: 0.4863 - accuracy: 0.3065
# Epoch 3/30
# 37/37 - 1s - loss: 0.4680 - accuracy: 0.3613
# Epoch 4/30
# 37/37 - 1s - loss: 0.4649 - accuracy: 0.3767
# Epoch 5/30
# 37/37 - 1s - loss: 0.4576 - accuracy: 0.3853
# Epoch 6/30
# 37/37 - 1s - loss: 0.4470 - accuracy: 0.4212
# Epoch 7/30
# 37/37 - 1s - loss: 0.4467 - accuracy: 0.4058
# Epoch 8/30
# 37/37 - 1s - loss: 0.4401 - accuracy: 0.4298
# Epoch 9/30
# 37/37 - 1s - loss: 0.4324 - accuracy: 0.4606
# Epoch 10/30
# 37/37 - 1s - loss: 0.4235 - accuracy: 0.4418
# Epoch 11/30
# 37/37 - 1s - loss: 0.4097 - accuracy: 0.4880
# Epoch 12/30
# 37/37 - 1s - loss: 0.4091 - accuracy: 0.4760
# Epoch 13/30
# 37/37 - 1s - loss: 0.4055 - accuracy: 0.5137
# Epoch 14/30
# 37/37 - 1s - loss: 0.3955 - accuracy: 0.5188
# Epoch 15/30
# 37/37 - 1s - loss: 0.3917 - accuracy: 0.5188
# Epoch 16/30
# 37/37 - 1s - loss: 0.3923 - accuracy: 0.5240
# Epoch 17/30
# 37/37 - 1s - loss: 0.3830 - accuracy: 0.5479
# Epoch 18/30
# 37/37 - 1s - loss: 0.3801 - accuracy: 0.5565
# Epoch 19/30
# 37/37 - 1s - loss: 0.3731 - accuracy: 0.5668
# Epoch 20/30
# 37/37 - 1s - loss: 0.3498 - accuracy: 0.6113
# Epoch 21/30
# 37/37 - 1s - loss: 0.3526 - accuracy: 0.6130
# Epoch 22/30
# 37/37 - 1s - loss: 0.3328 - accuracy: 0.6284
# Epoch 23/30
# 37/37 - 1s - loss: 0.3334 - accuracy: 0.6250
# Epoch 24/30
# 37/37 - 1s - loss: 0.3188 - accuracy: 0.6387
# Epoch 25/30
# 37/37 - 1s - loss: 0.3271 - accuracy: 0.6216
# Epoch 26/30
# 37/37 - 1s - loss: 0.3099 - accuracy: 0.6678
# Epoch 27/30
# 37/37 - 1s - loss: 0.3047 - accuracy: 0.6815
# Epoch 28/30
# 37/37 - 1s - loss: 0.2929 - accuracy: 0.6884
# Epoch 29/30
# 37/37 - 1s - loss: 0.2943 - accuracy: 0.6952
# Epoch 30/30
# 37/37 - 1s - loss: 0.2787 - accuracy: 0.7295
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 485
# Incorrect MI Prediction: 99
# Percent Accuracy: 83.048%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 163
# Incorrect MI Prediction: 88
# Percent Accuracy: 64.940%
# #################################
# #################################
# [[ -0.    -0.    -0.   ... 180.99 182.17 180.76]
#  [ -0.    -0.    -0.   ... 205.43 203.22 203.87]
#  [ -0.    -0.    -0.   ...  46.47  54.16  53.86]
#  ...
#  [ -0.    -0.    -0.   ...  48.93  50.87  52.94]
#  [ -0.    -0.    -0.   ...   8.3    8.88   7.95]
#  [ -0.    -0.    -0.   ... -15.73 -18.4  -19.42]]
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_16 (LSTM)               (None, 21, 100)           564000
# _________________________________________________________________
# lstm_17 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_8 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 594,455
# Trainable params: 594,455
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 38/38 - 1s - loss: 0.5380 - accuracy: 0.1944
# Epoch 2/30
# 38/38 - 1s - loss: 0.4640 - accuracy: 0.4651
# Epoch 3/30
# 38/38 - 1s - loss: 0.4162 - accuracy: 0.6246
# Epoch 4/30
# 38/38 - 1s - loss: 0.3655 - accuracy: 0.6811
# Epoch 5/30
# 38/38 - 1s - loss: 0.3506 - accuracy: 0.6545
# Epoch 6/30
# 38/38 - 1s - loss: 0.3117 - accuracy: 0.6977
# Epoch 7/30
# 38/38 - 1s - loss: 0.2822 - accuracy: 0.7342
# Epoch 8/30
# 38/38 - 1s - loss: 0.2385 - accuracy: 0.7957
# Epoch 9/30
# 38/38 - 1s - loss: 0.2377 - accuracy: 0.7807
# Epoch 10/30
# 38/38 - 1s - loss: 0.2500 - accuracy: 0.7492
# Epoch 11/30
# 38/38 - 1s - loss: 0.2487 - accuracy: 0.7558
# Epoch 12/30
# 38/38 - 1s - loss: 0.2025 - accuracy: 0.8106
# Epoch 13/30
# 38/38 - 1s - loss: 0.1833 - accuracy: 0.8106
# Epoch 14/30
# 38/38 - 1s - loss: 0.2078 - accuracy: 0.7957
# Epoch 15/30
# 38/38 - 1s - loss: 0.1882 - accuracy: 0.8223
# Epoch 16/30
# 38/38 - 1s - loss: 0.1607 - accuracy: 0.8472
# Epoch 17/30
# 38/38 - 1s - loss: 0.1618 - accuracy: 0.8472
# Epoch 18/30
# 38/38 - 1s - loss: 0.1635 - accuracy: 0.8472
# Epoch 19/30
# 38/38 - 1s - loss: 0.1462 - accuracy: 0.8704
# Epoch 20/30
# 38/38 - 1s - loss: 0.1259 - accuracy: 0.8920
# Epoch 21/30
# 38/38 - 1s - loss: 0.1300 - accuracy: 0.8804
# Epoch 22/30
# 38/38 - 1s - loss: 0.1330 - accuracy: 0.8704
# Epoch 23/30
# 38/38 - 1s - loss: 0.1200 - accuracy: 0.8987
# Epoch 24/30
# 38/38 - 1s - loss: 0.1033 - accuracy: 0.8987
# Epoch 25/30
# 38/38 - 1s - loss: 0.1128 - accuracy: 0.8953
# Epoch 26/30
# 38/38 - 1s - loss: 0.1155 - accuracy: 0.8937
# Epoch 27/30
# 38/38 - 1s - loss: 0.1310 - accuracy: 0.8771
# Epoch 28/30
# 38/38 - 1s - loss: 0.1491 - accuracy: 0.8654
# Epoch 29/30
# 38/38 - 1s - loss: 0.1052 - accuracy: 0.9103
# Epoch 30/30
# 38/38 - 1s - loss: 0.1126 - accuracy: 0.8953
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 576
# Incorrect MI Prediction: 26
# Percent Accuracy: 95.681%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 143
# Incorrect MI Prediction: 115
# Percent Accuracy: 55.426%
# #################################
# #################################
# Epoch 1/30
# 38/38 - 1s - loss: 0.5766 - accuracy: 0.2890
# Epoch 2/30
# 38/38 - 1s - loss: 0.4528 - accuracy: 0.4086
# Epoch 3/30
# 38/38 - 1s - loss: 0.4111 - accuracy: 0.5199
# Epoch 4/30
# 38/38 - 1s - loss: 0.3815 - accuracy: 0.5548
# Epoch 5/30
# 38/38 - 1s - loss: 0.3623 - accuracy: 0.5781
# Epoch 6/30
# 38/38 - 1s - loss: 0.3476 - accuracy: 0.6196
# Epoch 7/30
# 38/38 - 1s - loss: 0.3265 - accuracy: 0.6545
# Epoch 8/30
# 38/38 - 1s - loss: 0.3181 - accuracy: 0.6561
# Epoch 9/30
# 38/38 - 1s - loss: 0.3043 - accuracy: 0.6744
# Epoch 10/30
# 38/38 - 1s - loss: 0.2820 - accuracy: 0.7010
# Epoch 11/30
# 38/38 - 1s - loss: 0.2723 - accuracy: 0.7193
# Epoch 12/30
# 38/38 - 1s - loss: 0.2497 - accuracy: 0.7375
# Epoch 13/30
# 38/38 - 1s - loss: 0.2524 - accuracy: 0.7492
# Epoch 14/30
# 38/38 - 1s - loss: 0.2591 - accuracy: 0.7309
# Epoch 15/30
# 38/38 - 1s - loss: 0.2430 - accuracy: 0.7558
# Epoch 16/30
# 38/38 - 1s - loss: 0.2364 - accuracy: 0.7674
# Epoch 17/30
# 38/38 - 1s - loss: 0.2325 - accuracy: 0.7591
# Epoch 18/30
# 38/38 - 1s - loss: 0.2093 - accuracy: 0.8206
# Epoch 19/30
# 38/38 - 1s - loss: 0.1976 - accuracy: 0.8040
# Epoch 20/30
# 38/38 - 1s - loss: 0.1892 - accuracy: 0.8206
# Epoch 21/30
# 38/38 - 1s - loss: 0.1714 - accuracy: 0.8455
# Epoch 22/30
# 38/38 - 1s - loss: 0.1549 - accuracy: 0.8771
# Epoch 23/30
# 38/38 - 1s - loss: 0.1444 - accuracy: 0.8787
# Epoch 24/30
# 38/38 - 1s - loss: 0.1345 - accuracy: 0.8887
# Epoch 25/30
# 38/38 - 1s - loss: 0.1245 - accuracy: 0.9003
# Epoch 26/30
# 38/38 - 1s - loss: 0.1279 - accuracy: 0.8904
# Epoch 27/30
# 38/38 - 1s - loss: 0.1266 - accuracy: 0.8854
# Epoch 28/30
# 38/38 - 1s - loss: 0.1135 - accuracy: 0.9136
# Epoch 29/30
# 38/38 - 1s - loss: 0.1164 - accuracy: 0.9120
# Epoch 30/30
# 38/38 - 1s - loss: 0.1225 - accuracy: 0.9053
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 565
# Incorrect MI Prediction: 37
# Percent Accuracy: 93.854%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 186
# Incorrect MI Prediction: 72
# Percent Accuracy: 72.093%
# #################################
# #################################
# [[ -0.    -0.    -0.   ...  28.09  30.08  35.22]
#  [ -0.    -0.    -0.   ... -30.33 -30.12 -27.2 ]
#  [ -0.    -0.    -0.   ...  -3.24  -4.99   0.59]
#  ...
#  [ -0.    -0.    -0.   ...  -1.41  -2.37   0.72]
#  [ -0.    -0.    -0.   ... -11.75 -12.14  -8.93]
#  [ -0.    -0.    -0.   ... -14.77 -14.66 -11.33]]
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_18 (LSTM)               (None, 21, 100)           550400
# _________________________________________________________________
# lstm_19 (LSTM)               (None, 50)                30200
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 255
# =================================================================
# Total params: 580,855
# Trainable params: 580,855
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/30
# 38/38 - 1s - loss: 0.5404 - accuracy: 0.2331
# Epoch 2/30
# 38/38 - 1s - loss: 0.4824 - accuracy: 0.3636
# Epoch 3/30
# 38/38 - 1s - loss: 0.4582 - accuracy: 0.4727
# Epoch 4/30
# 38/38 - 1s - loss: 0.4356 - accuracy: 0.5339
# Epoch 5/30
# 38/38 - 1s - loss: 0.4232 - accuracy: 0.5223
# Epoch 6/30
# 38/38 - 1s - loss: 0.4190 - accuracy: 0.4975
# Epoch 7/30
# 38/38 - 1s - loss: 0.3994 - accuracy: 0.5372
# Epoch 8/30
# 38/38 - 1s - loss: 0.3946 - accuracy: 0.5504
# Epoch 9/30
# 38/38 - 1s - loss: 0.3777 - accuracy: 0.5636
# Epoch 10/30
# 38/38 - 1s - loss: 0.3639 - accuracy: 0.5950
# Epoch 11/30
# 38/38 - 1s - loss: 0.3566 - accuracy: 0.5901
# Epoch 12/30
# 38/38 - 1s - loss: 0.3547 - accuracy: 0.5983
# Epoch 13/30
# 38/38 - 1s - loss: 0.3340 - accuracy: 0.6331
# Epoch 14/30
# 38/38 - 1s - loss: 0.3179 - accuracy: 0.6612
# Epoch 15/30
# 38/38 - 1s - loss: 0.3030 - accuracy: 0.6694
# Epoch 16/30
# 38/38 - 1s - loss: 0.2993 - accuracy: 0.6562
# Epoch 17/30
# 38/38 - 1s - loss: 0.3029 - accuracy: 0.6529
# Epoch 18/30
# 38/38 - 1s - loss: 0.2904 - accuracy: 0.6959
# Epoch 19/30
# 38/38 - 1s - loss: 0.2742 - accuracy: 0.7025
# Epoch 20/30
# 38/38 - 1s - loss: 0.2990 - accuracy: 0.6893
# Epoch 21/30
# 38/38 - 1s - loss: 0.2991 - accuracy: 0.6595
# Epoch 22/30
# 38/38 - 1s - loss: 0.2656 - accuracy: 0.7322
# Epoch 23/30
# 38/38 - 1s - loss: 0.2711 - accuracy: 0.7074
# Epoch 24/30
# 38/38 - 1s - loss: 0.2564 - accuracy: 0.7256
# Epoch 25/30
# 38/38 - 1s - loss: 0.2663 - accuracy: 0.7174
# Epoch 26/30
# 38/38 - 1s - loss: 0.2431 - accuracy: 0.7504
# Epoch 27/30
# 38/38 - 1s - loss: 0.2431 - accuracy: 0.7620
# Epoch 28/30
# 38/38 - 1s - loss: 0.2416 - accuracy: 0.7306
# Epoch 29/30
# 38/38 - 1s - loss: 0.2411 - accuracy: 0.7488
# Epoch 30/30
# 38/38 - 2s - loss: 0.2537 - accuracy: 0.7140
# #################################
# #################################
# Training Performance:
# Correct MI Prediction: 524
# Incorrect MI Prediction: 81
# Percent Accuracy: 86.612%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 128
# Incorrect MI Prediction: 132
# Percent Accuracy: 49.231%
# #################################
# #################################
# Epoch 1/30
# 38/38 - 1s - loss: 0.5345 - accuracy: 0.2975
# Epoch 2/30
# 38/38 - 1s - loss: 0.4689 - accuracy: 0.3372
# Epoch 3/30
# 38/38 - 1s - loss: 0.4445 - accuracy: 0.4380
# Epoch 4/30
# 38/38 - 1s - loss: 0.4264 - accuracy: 0.4496
# Epoch 5/30
# 38/38 - 1s - loss: 0.4209 - accuracy: 0.4810
# Epoch 6/30
# 38/38 - 1s - loss: 0.4059 - accuracy: 0.5157
# Epoch 7/30
# 38/38 - 1s - loss: 0.3913 - accuracy: 0.5455
# Epoch 8/30
# 38/38 - 1s - loss: 0.3843 - accuracy: 0.5603
# Epoch 9/30
# 38/38 - 1s - loss: 0.3699 - accuracy: 0.5868
# Epoch 10/30
# 38/38 - 1s - loss: 0.3521 - accuracy: 0.6132
# Epoch 11/30
# 38/38 - 1s - loss: 0.3475 - accuracy: 0.6281
# Epoch 12/30
# 38/38 - 1s - loss: 0.3512 - accuracy: 0.6132
# Epoch 13/30
# 38/38 - 1s - loss: 0.3414 - accuracy: 0.6215
# Epoch 14/30
# 38/38 - 1s - loss: 0.3309 - accuracy: 0.6529
# Epoch 15/30
# 38/38 - 1s - loss: 0.3129 - accuracy: 0.6612
# Epoch 16/30
# 38/38 - 1s - loss: 0.2936 - accuracy: 0.6926
# Epoch 17/30
# 38/38 - 1s - loss: 0.2892 - accuracy: 0.6893
# Epoch 18/30
# 38/38 - 1s - loss: 0.2967 - accuracy: 0.6595
# Epoch 19/30
# 38/38 - 1s - loss: 0.2961 - accuracy: 0.6661
# Epoch 20/30
# 38/38 - 1s - loss: 0.2886 - accuracy: 0.6810
# Epoch 21/30
# 38/38 - 1s - loss: 0.3006 - accuracy: 0.6760
# Epoch 22/30
# 38/38 - 1s - loss: 0.2876 - accuracy: 0.6711
# Epoch 23/30
# 38/38 - 1s - loss: 0.2851 - accuracy: 0.6860
# Epoch 24/30
# 38/38 - 1s - loss: 0.2736 - accuracy: 0.7207
# Epoch 25/30
# 38/38 - 1s - loss: 0.2642 - accuracy: 0.7372
# Epoch 26/30
# 38/38 - 1s - loss: 0.2562 - accuracy: 0.7207
# Epoch 27/30
# 38/38 - 1s - loss: 0.2411 - accuracy: 0.7554
# Epoch 28/30
# 38/38 - 1s - loss: 0.2265 - accuracy: 0.7967
# Epoch 29/30
# 38/38 - 1s - loss: 0.2261 - accuracy: 0.7653
# Epoch 30/30
# 38/38 - 1s - loss: 0.2240 - accuracy: 0.7669
# #################################
# ### RESULTS AFTER APPLYING CSP ##
# #################################
# Training Performance:
# Correct MI Prediction: 519
# Incorrect MI Prediction: 86
# Percent Accuracy: 85.785%
# #################################
# #################################
# Testing Performance:
# Correct MI Prediction: 173
# Incorrect MI Prediction: 87
# Percent Accuracy: 66.538%
# #################################
# #################################

# %%
fileNames
# Out:
# ['5F-SubjectB-160309-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectB-160311-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectC-160429-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectE-160321-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectF-160210-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectG-160413-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectG-160428-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectH-160804-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectI-160719-5St-SGLHand-HFREQ.mat',
#  '5F-SubjectI-160723-5St-SGLHand-HFREQ.mat']

# %%
testAccuracyNoCSP
# Out:
# array([[46.66666667, 56.15384615, 62.74509804, 46.15384615, 58.07692308,
#         59.4488189 , 59.61538462, 49.40239044, 55.42635659, 49.23076923]])

# %%
testAccuracyWithCSP
# Out:
# array([[87.45098039, 81.53846154, 81.17647059, 67.69230769, 52.69230769,
#         87.00787402, 88.46153846, 64.94023904, 72.09302326, 66.53846154]])

# %%
trainAccuracyNoCSP
# Out:
# array([[96.97478992, 98.01652893, 97.64705882, 96.69421488, 99.00826446,
#         89.678511  , 86.61157025, 87.84246575, 95.68106312, 86.61157025]])

# %%
trainAccuracyWithCSP
# Out:
# array([[100.        ,  98.34710744, 100.        ,  96.52892562,
#          91.57024793,  99.83079526, 100.        ,  83.04794521,
#          93.8538206 ,  85.78512397]])

# %%
combinedArray = np.transpose(np.asarray(np.vstack((trainAccuracyNoCSP,testAccuracyNoCSP,trainAccuracyWithCSP, testAccuracyWithCSP))))

# %%
combinedArray.shape
# Out:
# (10, 4)

# %%
np.savetxt('5FperSubject.csv', combinedArray, delimiter=',')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1446                 try:
# -> 1447                     v = format % tuple(row) + newline
#    1448                 except TypeError:
#
# TypeError: must be real number, not numpy.str_
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-75d500d383ed> in <module>
# ----> 1 np.savetxt('5FperSubject.csv', combinedArray, delimiter=',')
#
# <__array_function__ internals> in savetxt(*args, **kwargs)
#
# /usr/local/lib/python3.7/site-packages/numpy/lib/npyio.py in savetxt(fname, X, fmt, delimiter, newline, header, footer, comments, encoding)
#    1449                     raise TypeError("Mismatch between array dtype ('%s') and "
#    1450                                     "format specifier ('%s')"
# -> 1451                                     % (str(X.dtype), format))
#    1452                 fh.write(v)
#    1453
#
# TypeError: Mismatch between array dtype ('<U40') and format specifier ('%.18e,%.18e,%.18e,%.18e,%.18e,%.18e,%.18e,%.18e,%.18e,%.18e')
